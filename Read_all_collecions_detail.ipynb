# %%
import pandas as pd

collections_df = pd.read_csv('collection_appear_4.csv', index_col=[0])
collections_df
# Out:
#                           symbol  #_appear
# 0                lux_real_estate         4
# 1                        portals         4
# 2                     solbouncer         4
# 3              solana_money_boys         4
# 4             solana_hodl_whales         4
# 5        shadowy_super_coder_dao         4
# 6                         degods         4
# 7            desolates_metaverse         4
# 8                   diamond_town         4
# 9                     robo_cocks         4
# 10               quantum_traders         4
# 11         famous_fox_federation         4
# 12         portals_citizen_cards         4
# 13               galactic_geckos         4
# 14                       solgods         4
# 15                    nuked_apes         4
# 16                 monkelabs_dao         4
# 17           ghostguys_metaforge         4
# 18                     monkelabs         4
# 19             guild_saga_heroes         4
# 20             honey_genesis_bee         4
# ...

# %%
# create a for loop to get all collection symbol under symbol column
for s in range(len(collections_df['symbol'])):
    print("symbol name: ",collections_df['symbol'][s])
# Out:
# symbol name:  lux_real_estate
# symbol name:  portals
# symbol name:  solbouncer
# symbol name:  solana_money_boys
# symbol name:  solana_hodl_whales
# symbol name:  shadowy_super_coder_dao
# symbol name:  degods
# symbol name:  desolates_metaverse
# symbol name:  diamond_town
# symbol name:  robo_cocks
# symbol name:  quantum_traders
# symbol name:  famous_fox_federation
# symbol name:  portals_citizen_cards
# symbol name:  galactic_geckos
# symbol name:  solgods
# symbol name:  nuked_apes
# symbol name:  monkelabs_dao
# symbol name:  ghostguys_metaforge
# symbol name:  monkelabs
# symbol name:  guild_saga_heroes
# symbol name:  honey_genesis_bee
# symbol name:  iconicapeclub3d
# symbol name:  monke_crew
# symbol name:  lifinity_flares
# symbol name:  888_anon_club
# symbol name:  magicticket
# symbol name:  defi_pirates
# symbol name:  degenerate_ape_academy
# symbol name:  space_runners
# symbol name:  the_remnants_
# symbol name:  zilla_vs_kong
# symbol name:  zankoku
# ...

# %%
# create a for loop to get all collection symbol under symbol column
# sep='' : with no space front/back of input value

li=[]
name = []

for s in range(len(collections_df['symbol'])):
    s_name = collections_df['symbol'][s]
    #s_list = print("solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/",s_name,".csv",sep='')
    li.append("solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/"+s_name+".csv")
    name.append(s_name+"_df")

# %%
li
# print(len(li))
# Out:
# ['solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/lux_real_estate.csv',
#  'solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/portals.csv',
#  'solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/solbouncer.csv',
#  'solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/solana_money_boys.csv',
#  'solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/solana_hodl_whales.csv',
#  'solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/shadowy_super_coder_dao.csv',
#  'solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/degods.csv',
#  'solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/desolates_metaverse.csv',
#  'solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/diamond_town.csv',
#  'solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/robo_cocks.csv',
#  'solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/quantum_traders.csv',
# ...

# %%
name
# print(len(name))
# Out:
# ['lux_real_estate_df',
#  'portals_df',
#  'solbouncer_df',
#  'solana_money_boys_df',
#  'solana_hodl_whales_df',
#  'shadowy_super_coder_dao_df',
#  'degods_df',
#  'desolates_metaverse_df',
#  'diamond_town_df',
#  'robo_cocks_df',
#  'quantum_traders_df',
#  'famous_fox_federation_df',
#  'portals_citizen_cards_df',
#  'galactic_geckos_df',
#  'solgods_df',
#  'nuked_apes_df',
#  'monkelabs_dao_df',
#  'ghostguys_metaforge_df',
#  'monkelabs_df',
#  'guild_saga_heroes_df',
#  'honey_genesis_bee_df',
#  'iconicapeclub3d_df',
#  'monke_crew_df',
#  'lifinity_flares_df',
#  '888_anon_club_df',
#  'magicticket_df',
#  'defi_pirates_df',
#  'degenerate_ape_academy_df',
#  'space_runners_df',
#  'the_remnants__df',
#  'zilla_vs_kong_df',
#  'zankoku_df',
#  'aldermages_df',
#  'almost_famous_pandas_df',
#  'yaku_corp_df',
#  'balloonsville_df',
#  'best_buds_df',
#  'bohemia__df',
#  'thugbirdz_df',
#  'boryoku_dragonz_df',
#  'dazedducks_metagalactic_club_df',
#  'the_suites_df',
# ...

# %%
col_list = ['id','price', 'owner', 'collectionName','collectionTitle','title','propertyCategory','creators','attributes','properties', 'tokenDelegateValid'
,'rarity','tokenDelegate']
test_df = pd.read_csv('solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/guild_saga_heroes.csv', usecols=col_list)
test_df.columns
# Out:
# Index(['id', 'price', 'owner', 'collectionName', 'collectionTitle', 'title',
#        'propertyCategory', 'creators', 'attributes', 'properties',
#        'tokenDelegateValid', 'rarity', 'tokenDelegate'],
#       dtype='object')

# %%
test_df
# Out:
#                                                id    price  \
# 0    ChXDGUBThc8frb7qsoUdiSZLpSGjhXhaK2U13pzDk3w4     1.35
# 1    DXywnmhtsPiob913Q8WYwEL37YkCEGBH4zXH7TRnUvSp     1.47
# 2     E1eQxXxBb7TYneHcvx1ZBUAnhSw1WyXcyc9uJaQB4WC     1.49
# 3    8ARxCQEsvYQLQxoFDHvbQXhABgqMrAohr2b1SvwMhY9x     1.50
# 4    GrzQAfPNzqLhmSG7ox5EnGynqkxCom27EMJHoPJAmYBf     1.50
# ..                                            ...      ...
# 773   5ck3nv9cTSKj8EqFPAo38mwFhtAzyUcNYYsk79SZDJN     1.95
# 774  7242mhwggHrwm1oBPmYC4eDxjr5QyNnLqPCNPqdWGjqf   200.00
# 775  9v4NV9MgP1aa3bGZ45BkRU96TKqBrJSFkAQSRa6ZRfb3   400.00
# 776  42cJpFmMaCgNZ3p42XyqheFUVqECQLCsGxK8no1HbVxb   500.00
# 777  7niyPmjmTURbMRxLdTsW85G6vRG33fCvWcJ8HQHbiLcF  1000.00
#
#                                             owner     collectionName  \
# 0    5cF6M4b1GEjzqBPJvAh5FqVmcerJabadtH4amjQUQnfu  guild_saga_heroes
# 1    ARxzW9chM1wNFFGMWxvakCP86JB1KUiHm31dCEvJcJyx  guild_saga_heroes
# ...

# %%
v4_list = []
col_list = ['id','price', 'owner', 'collectionName','collectionTitle','title','propertyCategory','creators','attributes','properties', 'tokenDelegateValid'
,'rarity']
for x in range(len(li)):
    df = pd.read_csv(li[0], usecols=col_list)
    v4_list.append(df)

# %%
v4_list[0]
# Out:
#                                                id    price  \
# 0    ETxb6zpF8refCBHhL5ZSeDrQ6xSdJEPCFzJsP9kFdUoo     4.20
# 1    33AzfMvCsXDuecu9zDJpxkUYRRg2SqMBeBeJVfvN7nZE     4.29
# 2    5ryBHks4YfTBQfCo7KUWyC3rxb7eXbk8ZvUgmJHnAU6u     4.35
# 3    93E7khVATXPJRgHSmhU3gG85titdFf2gn6LugBdMwhHu     4.40
# 4    2haYorntZh7ianRgGJWL8hxhmvCY1Yiy4ci2oXodjgk9     4.48
# ..                                            ...      ...
# 199  9EzSjkDL3Yq2heHEMBY2tFbPuNbHz6CWxzSorNEoSTgc   220.00
# 200  B9U5ZiDwssJpM1ue2QjQQdoLbuAQNGhVkk4h6UcG9tVq   333.00
# 201  FLneXt2nCKRLWUPqEQ5qi4QL3WLFCbUopSEaBZMwsPcw   420.00
# 202  9S6goxSzDpuaAszo7U2ArJLCd7qwSkpnqFmDkRwaVEPF  1000.00
# 203  6Nw5hhBSMAjZtBux5HArwyRMistRreg7dJxY4RiRbkUy  1500.00
#
#                                             owner   collectionName  \
# 0    7zDk3v9XG56iRDnEvQvQEeaLyt5ZAGxUeXCbN3mS7LaX  lux_real_estate
# 1    CkUaiQZbVzrQRiHsvG2EVm711NefUo6VVn9jxc7ZDJdc  lux_real_estate
# ...

# %%
v4_df = pd.concat(v1_list, axis=0, ignore_index=True)
v4_df
# Out:
#                                                  id    price  \
# 0      ETxb6zpF8refCBHhL5ZSeDrQ6xSdJEPCFzJsP9kFdUoo     4.20
# 1      33AzfMvCsXDuecu9zDJpxkUYRRg2SqMBeBeJVfvN7nZE     4.29
# 2      5ryBHks4YfTBQfCo7KUWyC3rxb7eXbk8ZvUgmJHnAU6u     4.35
# 3      93E7khVATXPJRgHSmhU3gG85titdFf2gn6LugBdMwhHu     4.40
# 4      2haYorntZh7ianRgGJWL8hxhmvCY1Yiy4ci2oXodjgk9     4.48
# ...                                             ...      ...
# 10195  9EzSjkDL3Yq2heHEMBY2tFbPuNbHz6CWxzSorNEoSTgc   220.00
# 10196  B9U5ZiDwssJpM1ue2QjQQdoLbuAQNGhVkk4h6UcG9tVq   333.00
# 10197  FLneXt2nCKRLWUPqEQ5qi4QL3WLFCbUopSEaBZMwsPcw   420.00
# 10198  9S6goxSzDpuaAszo7U2ArJLCd7qwSkpnqFmDkRwaVEPF  1000.00
# 10199  6Nw5hhBSMAjZtBux5HArwyRMistRreg7dJxY4RiRbkUy  1500.00
#
#                                               owner   collectionName  \
# 0      7zDk3v9XG56iRDnEvQvQEeaLyt5ZAGxUeXCbN3mS7LaX  lux_real_estate
# 1      CkUaiQZbVzrQRiHsvG2EVm711NefUo6VVn9jxc7ZDJdc  lux_real_estate
# ...

# %%
v4_df['version'] = "4"
v4_df
# Out:
#                                                  id    price  \
# 0      ETxb6zpF8refCBHhL5ZSeDrQ6xSdJEPCFzJsP9kFdUoo     4.20
# 1      33AzfMvCsXDuecu9zDJpxkUYRRg2SqMBeBeJVfvN7nZE     4.29
# 2      5ryBHks4YfTBQfCo7KUWyC3rxb7eXbk8ZvUgmJHnAU6u     4.35
# 3      93E7khVATXPJRgHSmhU3gG85titdFf2gn6LugBdMwhHu     4.40
# 4      2haYorntZh7ianRgGJWL8hxhmvCY1Yiy4ci2oXodjgk9     4.48
# ...                                             ...      ...
# 10195  9EzSjkDL3Yq2heHEMBY2tFbPuNbHz6CWxzSorNEoSTgc   220.00
# 10196  B9U5ZiDwssJpM1ue2QjQQdoLbuAQNGhVkk4h6UcG9tVq   333.00
# 10197  FLneXt2nCKRLWUPqEQ5qi4QL3WLFCbUopSEaBZMwsPcw   420.00
# 10198  9S6goxSzDpuaAszo7U2ArJLCd7qwSkpnqFmDkRwaVEPF  1000.00
# 10199  6Nw5hhBSMAjZtBux5HArwyRMistRreg7dJxY4RiRbkUy  1500.00
#
#                                               owner   collectionName  \
# 0      7zDk3v9XG56iRDnEvQvQEeaLyt5ZAGxUeXCbN3mS7LaX  lux_real_estate
# 1      CkUaiQZbVzrQRiHsvG2EVm711NefUo6VVn9jxc7ZDJdc  lux_real_estate
# ...

# %%
li_v1=[]

for s in range(len(collections_df['symbol'])):
    s_name = collections_df['symbol'][s]
    #s_list = print("solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/",s_name,".csv",sep='')
    li_v1.append("solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/"+s_name+".csv")

li_v1
# Out:
# ['solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/lux_real_estate.csv',
#  'solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/portals.csv',
#  'solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/solbouncer.csv',
#  'solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/solana_money_boys.csv',
#  'solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/solana_hodl_whales.csv',
#  'solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/shadowy_super_coder_dao.csv',
#  'solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/degods.csv',
#  'solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/desolates_metaverse.csv',
#  'solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/diamond_town.csv',
#  'solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/robo_cocks.csv',
#  'solana_nft_full/solana_v1/Solana_NFT_Collections_v1/collections/quantum_traders.csv',
# ...

# %%
v1_list = []
col_list = ['id','price', 'owner', 'collectionName','collectionTitle','title','propertyCategory','creators','attributes','properties', 'tokenDelegateValid'
]
for x in range(len(li_v1)):
    df = pd.read_csv(li_v1[0], usecols=col_list)
    v1_list.append(df)

v1_list
# Out:
# [                                               id    price  \
#  0    F6iQ92fh8xKHiH9FP1buvf8HRKpDzokTEP76W4YSqRe1     6.00
#  1    5VuXmx47uEnH1cP944VCBb8QWavo1vAtJYoxJXyhkpZ6     6.00
#  2    BCj4VZ742aQiNXgvGJQQvufSsWxsiNsEyA7FjS6JJPTe     6.20
#  3    9cRDL4YsPi5ftyg2HAkFgVmAKTApSvHp7wNprmVdYcmh     6.29
#  4    22hgT7q3APxKLQU2K5AzBqqUGHoP9xaJ2frR5AUSu1X1     6.30
#  ..                                            ...      ...
#  193  FLneXt2nCKRLWUPqEQ5qi4QL3WLFCbUopSEaBZMwsPcw   420.00
#  194  5UtGzpDPhGYJkfueBYMtNo9gjojCndLFAHaKovusMVKK   424.99
#  195  ESbJmHU4MiLNqg73tjPV3x3kextfsr4Jg7u5ADNPXTwR   777.00
#  196  5Mz8ZCQvDqUrT2kwz1VHEsDzhvtSEwu2wNkAq2X228Ky   999.00
#  197  5CGDJNceRzFgarkGiDUScSpFpT9wfjbcZj2UXH3aktyB  1499.00
#
#                                              owner   collectionName  \
#  0    H8poh3jCsRKxMmQh88ZojG61tU7DVejoeHx8B2Yisq8o  lux_real_estate
#  1    FeJKqEKi3ZszFC61oMReRBtKPNdHdKCJiekMw6LGJbg7  lux_real_estate
# ...

# %%
v1_df = pd.concat(v1_list, axis=0, ignore_index=True)
v1_df['rarity'] = "NaN"
v1_df['version'] = "1"
v1_df
# Out:
#                                                 id    price  \
# 0     F6iQ92fh8xKHiH9FP1buvf8HRKpDzokTEP76W4YSqRe1     6.00
# 1     5VuXmx47uEnH1cP944VCBb8QWavo1vAtJYoxJXyhkpZ6     6.00
# 2     BCj4VZ742aQiNXgvGJQQvufSsWxsiNsEyA7FjS6JJPTe     6.20
# 3     9cRDL4YsPi5ftyg2HAkFgVmAKTApSvHp7wNprmVdYcmh     6.29
# 4     22hgT7q3APxKLQU2K5AzBqqUGHoP9xaJ2frR5AUSu1X1     6.30
# ...                                            ...      ...
# 9895  FLneXt2nCKRLWUPqEQ5qi4QL3WLFCbUopSEaBZMwsPcw   420.00
# 9896  5UtGzpDPhGYJkfueBYMtNo9gjojCndLFAHaKovusMVKK   424.99
# 9897  ESbJmHU4MiLNqg73tjPV3x3kextfsr4Jg7u5ADNPXTwR   777.00
# 9898  5Mz8ZCQvDqUrT2kwz1VHEsDzhvtSEwu2wNkAq2X228Ky   999.00
# 9899  5CGDJNceRzFgarkGiDUScSpFpT9wfjbcZj2UXH3aktyB  1499.00
#
#                                              owner   collectionName  \
# 0     H8poh3jCsRKxMmQh88ZojG61tU7DVejoeHx8B2Yisq8o  lux_real_estate
# 1     FeJKqEKi3ZszFC61oMReRBtKPNdHdKCJiekMw6LGJbg7  lux_real_estate
# ...

# %%
print(v1_df.shape)
# Out:
# (9900, 13)

# %%
li_v2=[]

for s in range(len(collections_df['symbol'])):
    s_name = collections_df['symbol'][s]
    #s_list = print("solana_nft_full/solana_v4/Solana_NFT_Collections_v4/collections/",s_name,".csv",sep='')
    li_v2.append("solana_nft_full/solana_v2/Solana_NFT_Collections_v2/collections/"+s_name+".csv")

v2_list = []
col_list = ['id','price', 'owner', 'collectionName','collectionTitle','title','propertyCategory','creators','attributes','properties', 'tokenDelegateValid','rarity'
]
for x in range(len(li_v2)):
    df = pd.read_csv(li_v2[0], usecols=col_list)
    v2_list.append(df)

v2_df = pd.concat(v2_list, axis=0, ignore_index=True)
# v1_df['rarity'] = "NaN"
v2_df['version'] = "2"
v2_df
# Out:
#                                                  id      price  \
# 0      8bbakxAYwKwwsC1wm7xTGB5VbJP47hB81wgUuzr52nHM     4.2069
# 1      9Q2NACjhN3tD3WHYHEPZ1ATkKN8MsVgtGkwvgz3odhau     4.2200
# 2      5vBGHH2LmaZ7Vo18UefXx6fBQipQ8YVUT3cshT6Ratc6     4.2500
# 3      3Z9hgK79SkkCm4bBc2Z2rCaoMnQVMMpMaD2qjVGsLR7q     4.3500
# 4      9Hdu4ssPDUrhkWDa6DQsbVzHLuJoCVLdM3iuibgSQ5EJ     4.4000
# ...                                             ...        ...
# 11345  71wkGyBZWpn7No7ChoDCqqpnQUi8WzgBSY99qwANjssb   169.6969
# 11346  9EzSjkDL3Yq2heHEMBY2tFbPuNbHz6CWxzSorNEoSTgc   220.0000
# 11347  FLneXt2nCKRLWUPqEQ5qi4QL3WLFCbUopSEaBZMwsPcw   420.0000
# 11348  5UtGzpDPhGYJkfueBYMtNo9gjojCndLFAHaKovusMVKK   424.9900
# 11349  4owDHYLfchBAQ6wu52uexi6rjRBCrdEjjif1pEsiwKaF  1599.0000
#
#                                               owner   collectionName  \
# 0      9wr29aJj834PUcFq4h9m6ceJcMh4xtXafUXVAbD8rrLv  lux_real_estate
# ...

# %%
li_v3=[]

for s in range(len(collections_df['symbol'])):
    s_name = collections_df['symbol'][s]
    li_v3.append("solana_nft_full/solana_v3/Solana_NFT_Collections_v3/collections/"+s_name+".csv")

v3_list = []
col_list = ['id','price', 'owner', 'collectionName','collectionTitle','title','propertyCategory','creators','attributes','properties', 'tokenDelegateValid','rarity'
]
for x in range(len(li_v3)):
    df = pd.read_csv(li_v3[0], usecols=col_list)
    v3_list.append(df)

v3_df = pd.concat(v3_list, axis=0, ignore_index=True)
v3_df['version'] = "3"
v3_df
# Out:
#                                                 id    price  \
# 0     HwUKsaHeGvYmY9mQPVTbeTmHsE2yVazuCK5kRWRvy4M5     6.34
# 1     E2PvJCagwTcbifDzeapkjYn2DYeawVjRmECBnhhWsP8Y     6.35
# 2      nMw4YsiGDTNAG3JX7LB7YGXWcKoWt5WW84oLh9nfQh9     6.36
# 3     5jcfucM1m7QwRRBATeNZE5DTaGkktLxEaEHKcNP7aE1a     6.37
# 4     C8SHai583jmad679ibf7RyetTG8pQCdXL2Td4HiyQ9Yx     6.38
# ...                                            ...      ...
# 9045  7aQpZVeqxZUoC6MFrEeX7Kdj5eEQsXBP4Qd3Fugpm6qu  1000.00
# 9046  5sEcT8Uv6xBXBGEpDhjhFDUwgb41iFHShmSv8amE2LXu  2000.00
# 9047  9S6goxSzDpuaAszo7U2ArJLCd7qwSkpnqFmDkRwaVEPF  2000.00
# 9048  GYwsrZ6rAqGDe9dzTWYqw9oEGtij1gtMD2jT6z2JEvrL  2000.00
# 9049  CEZtu9U3GmZHh9cBGVn7A1YLpe94bLQ2MuDgV5kkineN  2000.00
#
#                                              owner   collectionName  \
# 0     5ooqSQZip4Y7BKoHMtVXT77fyz9UZPx4g7aw4atbVcJe  lux_real_estate
# 1     DRsUPyH38BcqG5eGMH6o9RusBjkkaJ2RtBMnUPCwxAqJ  lux_real_estate
# ...

# %%
print(v1_df.shape)
print(v2_df.shape)
print(v3_df.shape)
print(v4_df.shape)
# Out:
# (9900, 13)
# (11350, 13)
# (9050, 13)
# (10200, 13)

# %%
all_ver_frame = [v1_df,v2_df,v3_df,v4_df]
all_ver_df = pd.concat(all_ver_frame,axis=0, ignore_index=True)
print(all_ver_df.shape)
all_ver_df
# Out:
# (40500, 13)
#                                                  id    price  \
# 0      F6iQ92fh8xKHiH9FP1buvf8HRKpDzokTEP76W4YSqRe1     6.00
# 1      5VuXmx47uEnH1cP944VCBb8QWavo1vAtJYoxJXyhkpZ6     6.00
# 2      BCj4VZ742aQiNXgvGJQQvufSsWxsiNsEyA7FjS6JJPTe     6.20
# 3      9cRDL4YsPi5ftyg2HAkFgVmAKTApSvHp7wNprmVdYcmh     6.29
# 4      22hgT7q3APxKLQU2K5AzBqqUGHoP9xaJ2frR5AUSu1X1     6.30
# ...                                             ...      ...
# 40495  9EzSjkDL3Yq2heHEMBY2tFbPuNbHz6CWxzSorNEoSTgc   220.00
# 40496  B9U5ZiDwssJpM1ue2QjQQdoLbuAQNGhVkk4h6UcG9tVq   333.00
# 40497  FLneXt2nCKRLWUPqEQ5qi4QL3WLFCbUopSEaBZMwsPcw   420.00
# 40498  9S6goxSzDpuaAszo7U2ArJLCd7qwSkpnqFmDkRwaVEPF  1000.00
# 40499  6Nw5hhBSMAjZtBux5HArwyRMistRreg7dJxY4RiRbkUy  1500.00
#
#                                               owner   collectionName  \
# 0      H8poh3jCsRKxMmQh88ZojG61tU7DVejoeHx8B2Yisq8o  lux_real_estate
# 1      FeJKqEKi3ZszFC61oMReRBtKPNdHdKCJiekMw6LGJbg7  lux_real_estate
# ...

# %%
all_ver_df.to_csv('nft_collection_all_version.csv')
