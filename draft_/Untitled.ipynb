# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2022-05-14T16:01:33.430Z', 'error_code': 0, 'error_message': None, 'elapsed': 2, 'credit_count': 1, 'notice': None}, 'data': [{'id': 3733, 'name': 'dhipotqjzt8', 'symbol': '55ptaoheugy', 'slug': 'dx6i0cwaspk', 'cmc_rank': 4376, 'num_market_pairs': 637, 'circulating_supply': 2080, 'total_supply': 1252, 'max_supply': 3573, 'last_updated': '2022-05-14T16:01:33.429Z', 'date_added': '2022-05-14T16:01:33.429Z', 'tags': ['aeo7phwmyi', 'lf4shslsllg', 'fgc5kbatmi6', '49pph0gee1s', 'fkydsbxsjjc', 'fe7w538a284', 'yf4k25k1iq', 'gnu3l1uy2y8', 'gw00bruaxb', 't68m45l305'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.33723650929519655, 'volume_24h': 851, 'volume_change_24h': 0.9963099642713502, 'percent_change_1h': 0.38869697287810934, 'percent_change_24h': 0.3797441710360785, 'percent_change_7d': 0.97833609244019, 'market_cap': 0.5006848701423054, 'market_cap_dominance': 6444, 'fully_diluted_market_cap': 0.3542019717698053, 'last_updated': '2022-05-14T16:01:33.429Z'}}}, {'id': 7629, 'name': 'rkh1yqejg3r', 'symbol': 'jvorndhsmw', 'slug': 'cmvvqcu7lz', 'cmc_rank': 1493, 'num_market_pairs': 1103, 'circulating_supply': 2581, 'total_supply': 3507, 'max_supply': 288, 'last_updated': '2022-05-14T16:01:33.429Z', 'date_added': '2022-05-14T16:01:33.429Z', 'tags': ['m7cmzizazx', 'yech0fuh4jj', 'ut874n7nsx', 'yznx97ch89h', 'esjzpjxw8b9', '6parv20i10o', 'm6x06595d2s', 'yui4liv1p3g', 'nm3rs6zd8jj', 'oqa55eiyxe'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.8553000477902226, 'volume_24h': 9325, 'volume_change_24h': 0.9547995031481451, 'percent_change_1h': 0.26038030930385014, 'percent_change_24h': 0.4202781754192413, 'percent_change_7d': 0.9914071588387074, 'market_cap': 0.13101133195633108, 'market_cap_dominance': 857, 'fully_diluted_market_cap': 0.1690619136826892, 'last_updated': '2022-05-14T16:01:33.429Z'}}}, {'id': 1616, 'name': '3srbamplfld', 'symbol': '98nrqzg33cr', 'slug': 'mep7j4knt3a', 'cmc_rank': 9556, 'num_market_pairs': 9357, 'circulating_supply': 7802, 'total_supply': 775, 'max_supply': 6446, 'last_updated': '2022-05-14T16:01:33.429Z', 'date_added': '2022-05-14T16:01:33.429Z', 'tags': ['wzwr2nhbene', '8b1ht40fowb', 'gvcci0j188c', 'jer5ce16vyb', 'ug9g9mi66h', 'tzumr66ewek', 'vzaj2a55lac', '34p1k08b032', 'i3zmiuut4gm', 'e5ogsvvbzqe'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.8136658911403833, 'volume_24h': 4421, 'volume_change_24h': 0.6014343763538024, 'percent_change_1h': 0.4918549755655206, 'percent_change_24h': 0.6024809471017369, 'percent_change_7d': 0.006686794746768587, 'market_cap': 0.9564035457380566, 'market_cap_dominance': 9117, 'fully_diluted_market_cap': 0.06863988010994215, 'last_updated': '2022-05-14T16:01:33.429Z'}}}, {'id': 6968, 'name': '6bl6rur8vj', 'symbol': 'o76xaaqxc3c', 'slug': 'yzj3dv8g0r', 'cmc_rank': 189, 'num_market_pairs': 7885, 'circulating_supply': 2112, 'total_supply': 4364, 'max_supply': 1328, 'last_updated': '2022-05-14T16:01:33.429Z', 'date_added': '2022-05-14T16:01:33.429Z', 'tags': ['wq5i9q2eirg', 'o1bhc7ip6r', 'qzjrqm2uupp', 'ldd3pbq9z7k', '6mgj61whshd', '784qr18oafk', 'zq4tjzs1wb', 'nef82rwtjlo', 'rrklfbmgvf8', 'ucdkweiti3'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.018812666831955926, 'volume_24h': 8197, 'volume_change_24h': 0.5942768217902028, 'percent_change_1h': 0.43882449169392235, 'percent_change_24h': 0.7807434058865461, 'percent_change_7d': 0.8173166991690599, 'market_cap': 0.09897053972837933, 'market_cap_dominance': 2460, 'fully_diluted_market_cap': 0.6850546044018075, 'last_updated': '2022-05-14T16:01:33.429Z'}}}, {'id': 3018, 'name': 'o9steiydop', 'symbol': 'zpvd0lf7xw9', 'slug': '5oe0gfbjl93', 'cmc_rank': 4436, 'num_market_pairs': 7696, 'circulating_supp ...

# %%
data.keys()
# Out:
# dict_keys(['status', 'data'])

# %%
data["status"]
# Out:
# {'timestamp': '2022-05-14T14:58:24.227Z',
#  'error_code': 0,
#  'error_message': None,
#  'elapsed': 2,
#  'credit_count': 1,
#  'notice': None}

# %%
data["data"]
# Out:
# [{'id': 3288,
#   'name': 'eecv26ccyzk',
#   'symbol': 'tkcjd30o8tn',
#   'slug': '1pffqibq8',
#   'cmc_rank': 934,
#   'num_market_pairs': 2655,
#   'circulating_supply': 2441,
#   'total_supply': 794,
#   'max_supply': 2512,
#   'last_updated': '2022-05-14T14:58:24.226Z',
#   'date_added': '2022-05-14T14:58:24.226Z',
#   'tags': ['6xzwwomlwzi',
#    'yv5vm2kkuot',
#    '06kzktwtyncb',
#    '35evcrq2dh5',
#    'chq5u9piu1',
#    '115k6107hr8',
#    'z16gtymq7y',
#    '9ufg818ss9d',
#    'haufdtb1x78',
#    'r63fb16p4w'],
#   'platform': None,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'quote': {'USD': {'price': 0.5320816272962021,
#     'volume_24h': 3983,
#     'volume_change_24h': 0.09471904765681782,
#     'percent_change_1h': 0.9537780926971227,
#     'percent_change_24h': 0.0977834412432168,
#     'percent_change_7d': 0.9318361299487947,
#     'market_cap': 0.8007803240235374,
#     'market_cap_dominance': 9875,
#     'fully_diluted_market_cap': 0.7666423266916953,
#     'last_updated': '2022-05-14T14:58:24.226Z'}}},
#  {'id': 1686,
#   'name': '4nuytspfxfw',
#   'symbol': '20i9zn10ss6',
#   'slug': 'n5tkq9wdg0k',
#   'cmc_rank': 7897,
#   'num_market_pairs': 679,
#   'circulating_supply': 9941,
#   'total_supply': 4918,
#   'max_supply': 9062,
#   'last_updated': '2022-05-14T14:58:24.226Z',
#   'date_added': '2022-05-14T14:58:24.226Z',
#   'tags': ['ynn9lrp89gk',
#    'i8hjbgqvr',
#    'q04nbtl7iq',
#    '7vzkpq8wu6x',
#    'sumg8vgvu4r',
#    '2smfrsk8e4e',
#    'u3u0ch832t',
#    'if0ce8emytt',
#    'd9kzpdvrl',
#    '1af3f3ca1nb'],
#   'platform': None,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'quote': {'USD': {'price': 0.5184720548705686,
#     'volume_24h': 3860,
#     'volume_change_24h': 0.1732164371018481,
#     'percent_change_1h': 0.8815083127373267,
#     'percent_change_24h': 0.4132440854870456,
#     'percent_change_7d': 0.31122574573399,
#     'market_cap': 0.5867569075553583,
#     'market_cap_dominance': 7302,
#     'fully_diluted_market_cap': 0.19908811066969068,
#     'last_updated': '2022-05-14T14:58:24.226Z'}}},
#  {'id': 386,
#   'name': 'jfd4fu1kqq',
#   'symbol': '0pkohkvsfvlm',
#   'slug': 'gblt46sk3cd',
#   'cmc_rank': 9217,
#   'num_market_pairs': 378,
#   'circulating_supply': 8610,
#   'total_supply': 8716,
#   'max_supply': 5836,
#   'last_updated': '2022-05-14T14:58:24.226Z',
#   'date_added': '2022-05-14T14:58:24.226Z',
#   'tags': ['pz6ad02yvl',
#    'gx22jkg39sd',
#    'ofhrv6s1sy8',
#    'bq9a4qavtyg',
#    'twwp6i29j2',
#    '2i4z9wg19ug',
#    'rlmstmmwny',
#    '4eux60ln3ec',
#    'r27l1wd50em',
#    's6dk5t5xqc7'],
#   'platform': None,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'quote': {'USD': {'price': 0.1337304311109646,
#     'volume_24h': 5530,
#     'volume_change_24h': 0.44450901374407303,
#     'percent_change_1h': 0.8297236152932972,
#     'percent_change_24h': 0.5568179093104344,
#     'percent_change_7d': 0.7109513193782997,
#     'market_cap': 0.6703195064645424,
#     'market_cap_dominance': 7967,
#     'fully_diluted_market_cap': 0.054134539200094256,
#     'last_updated': '2022-05-14T14:58:24.226Z'}}},
#  {'id': 3521,
#   'name': 'ss7wmlc31h',
#   'symbol': 'q2plz85y7qg',
#   'slug': 'baf7wq2udq5',
#   'cmc_rank': 3426,
#   'num_market_pairs': 4456,
#   'circulating_supply': 1135,
#   'total_supply': 4695,
#   'max_supply': 8002,
#   'last_updated': '2022-05-14T14:58:24.226Z',
#   'date_added': '2022-05-14T14:58:24.226Z',
#   'tags': ['vcnzvxex0z',
#    'gqxutb8yd2v',
#    '8cre58804l7',
#    'u6sri1ocyu',
#    '2abp7lwx31c',
#    'rwiv53mzho9',
#    'v3poxbxqjo',
#    'q9iasw4pam',
#    'lox9hw1kdmq',
#    'xeh9npvdrt'],
#   'platform': None,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'quote': {'USD': {'price': 0.47630024615793065,
#     'volume_24h': 7024,
#     'volume_change_24h': 0.2557130508504062,
#     'percent_change_1h': 0.9988070787350267,
#     'percent_change_24h': 0.5956127823991444,
#     'percent_change_7d': 0.44484616358117335,
#     'market_cap': 0.4783234092910189,
#     'market_cap_dominance': 5082,
#     'fully_diluted_market_cap': 0.3120489975141345,
#     'last_updated': '2022-05-14T14:58:24.226Z'}}},
#  {'id': 2459,
#   'name': 'evlvrkb3vsu',
#   'symbol': 'cqpvxlmmzco',
#   'slug': 'mpkkkxqil2',
#   'cmc_rank': 319,
#   'num_market_pairs': 4084,
#   'circulating_supply': 9606,
#   'total_supply': 8032,
#   'max_supply': 3399,
#   'last_updated': '2022-05-14T14:58:24.226Z',
#   'date_added': '2022-05-14T14:58:24.226Z',
#   'tags': ['l16xtl7p1ca',
#    'y9ho9ma51nj',
#    '1vqe3a9bpw6',
#    'avbqjw8sah5',
#    '3088o1m6vvc',
#    '7hl2jnkt7mg',
#    'hsap0ibjd',
#    'edhj26ertl9',
#    'ne66kp0l2dn',
#    '89rt9b02dfy'],
#   'platform': None,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'quote': {'USD': {'price': 0.7216036488246866,
#     'volume_24h': 4999,
#     'volume_change_24h': 0.916947147808147,
#     'percent_change_1h': 0.3029458340196991,
#     'percent_change_24h': 0.4170390134451478,
#     'percent_change_7d': 0.7248793388124046,
#     'market_cap': 0.8256078958688926,
#     'market_cap_dominance': 7458,
#     'fully_diluted_market_cap': 0.9415977730985672,
#     'last_updated': '2022-05-14T14:58:24.226Z'}}},
#  {'id': 9743,
#   'name': '4eiom7aivn',
#   'symbol': 'td78zfj55d',
#   'slug': 'xszd5be8i6g',
#   'cmc_rank': 263,
#   'num_market_pairs': 2245,
#   'circulating_supply': 1873,
#   'total_supply': 1179,
#   'max_supply': 7792,
#   'last_updated': '2022-05-14T14:58:24.226Z',
#   'date_added': '2022-05-14T14:58:24.226Z',
#   'tags': ['n3yolohy3gl',
#    'b6wr3mn0oje',
#    'sfar4ygqi8s',
#    '75adtuj2qg',
#    '9odpl2d3wl',
#    '586ty3q79hc',
#    '8zw3ijg4m3m',
#    '67cyxnlj5xy',
#    '2tyt95d469o',
#    'gfn32u9k6lk'],
#   'platform': None,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'quote': {'USD': {'price': 0.8439845708001279,
#     'volume_24h': 9020,
#     'volume_change_24h': 0.22051585027171416,
#     'percent_change_1h': 0.11129424111229258,
#     'percent_change_24h': 0.997987610961802,
#     'percent_change_7d': 0.2914241150054895,
#     'market_cap': 0.0815624748497985,
#     'market_cap_dominance': 2845,
#     'fully_diluted_market_cap': 0.454042214917203,
#     'last_updated': '2022-05-14T14:58:24.227Z'}}},
#  {'id': 9112,
#   'name': 'nmtyvacd2y',
#   'symbol': 'xspj8ixqev',
#   'slug': 'szo7oloeet',
#   'cmc_rank': 3013,
#   'num_market_pairs': 2934,
#   'circulating_supply': 2997,
#   'total_supply': 132,
#   'max_supply': 541,
#   'last_updated': '2022-05-14T14:58:24.227Z',
#   'date_added': '2022-05-14T14:58:24.227Z',
#   'tags': ['2jhj5gaqamn',
#    'sw5ddou8ml',
#    'f7i6n6es69',
#    'pj8wi7x32rr',
#    'gxfzrnuqw58',
#    'oeadozzom4',
#    'hkf5cyuchqg',
#    'btlr0sjb0r',
#    'v0r1z7yls9d',
#    'k6peuoemyb'],
#   'platform': None,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'quote': {'USD': {'price': 0.3274556402033275,
#     'volume_24h': 1067,
#     'volume_change_24h': 0.3274362214388584,
#     'percent_change_1h': 0.2978695653592631,
#     'percent_change_24h': 0.7256267845247113,
#     'percent_change_7d': 0.030744427053180923,
#     'market_cap': 0.24651581096900532,
#     'market_cap_dominance': 8752,
#     'fully_diluted_market_cap': 0.646071014193154,
#     'last_updated': '2022-05-14T14:58:24.227Z'}}},
#  {'id': 7637,
#   'name': 'bpdzcdosmc',
#   'symbol': 'ehwuvyzrbff',
#   'slug': '548uj2uwp0g',
#   'cmc_rank': 8722,
#   'num_market_pairs': 9632,
#   'circulating_supply': 2051,
#   'total_supply': 5996,
#   'max_supply': 8021,
#   'last_updated': '2022-05-14T14:58:24.227Z',
#   'date_added': '2022-05-14T14:58:24.227Z',
#   'tags': ['2flg64v9ly2',
#    '2zieic3b0l4',
#    'pb803pdt14',
#    'g0x19jho1z7',
#    's8bv07w6zk',
#    'rxlwfc1wy5a',
#    'n2yo6banl2e',
#    'fvkvibi99uq',
#    'asf2ojmyl9v',
#    'kuulgx0bca'],
#   'platform': None,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'quote': {'USD': {'price': 0.7213479728730827,
#     'volume_24h': 8476,
#     'volume_change_24h': 0.1505887838310238,
#     'percent_change_1h': 0.3750853084329109,
#     'percent_change_24h': 0.5809609676663519,
#     'percent_change_7d': 0.3454867213984565,
#     'market_cap': 0.1152077697737266,
#     'market_cap_dominance': 4040,
#     'fully_diluted_market_cap': 0.8749415455021798,
#     'last_updated': '2022-05-14T14:58:24.227Z'}}},
#  {'id': 6175,
#   'name': 'd3cbbay3k1i',
#   'symbol': 'f2hrpjqcohw',
#   'slug': 'brug0yi6k5',
#   'cmc_rank': 5496,
#   'num_market_pairs': 7360,
#   'circulating_supply': 1932,
#   'total_supply': 2760,
#   'max_supply': 9656,
#   'last_updated': '2022-05-14T14:58:24.227Z',
#   'date_added': '2022-05-14T14:58:24.227Z',
#   'tags': ['3icutyfe2fl',
#    '6dsknbv33q4',
#    'rz2b1lioptf',
#    'sifg6pw8hfh',
#    '7dctq0p3j3n',
#    '7chndd1tsu6',
#    'adhqsw8zmze',
#    'd0br6xacepv',
#    'ep67sza0up7',
#    'oaivu4dmzeh'],
#   'platform': None,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'quote': {'USD': {'price': 0.9227514453249033,
#     'volume_24h': 8767,
#     'volume_change_24h': 0.8090566114170097,
#     'percent_change_1h': 0.5376139463832461,
#     'percent_change_24h': 0.08825067438191825,
#     'percent_change_7d': 0.7569294417933661,
#     'market_cap': 0.3407239319794577,
#     'market_cap_dominance': 7943,
#     'fully_diluted_market_cap': 0.0056670443666071435,
#     'last_updated': '2022-05-14T14:58:24.227Z'}}},
#  {'id': 4521,
#   'name': '6x6s2pkc5cu',
#   'symbol': '95d38qtgq7q',
#   'slug': 'xmkefzi5oye',
#   'cmc_rank': 8058,
#   'num_market_pairs': 2737,
#   'circulating_supply': 3049,
#   'total_supply': 2230,
#   'max_supply': 6339,
#   'last_updated': '2022-05-14T14:58:24.227Z',
#   'date_added': '2022-05-14T14:58:24.227Z',
#   'tags': ['dpqdar6k5so',
#    'oqblak8i7a',
#    '3rtpi7ca9kr',
#    '0c15qbi7zblr',
#    'e4auw9rrv5o',
#    '07t039f8gnlk',
#    'g2hr7v466rr',
#    'sjmvo2oz1wp',
#    'whpcv4v54a8',
#    '5o3tco2jbl9'],
#   'platform': None,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'quote': {'USD': {'price': 0.4028321097069796,
#     'volume_24h': 8589,
#     'volume_change_24h': 0.8510281318306516,
#     'percent_change_1h': 0.47765940078460445,
#     'percent_change_24h': 0.15738982512626598,
#     'percent_change_7d': 0.04379598481192448,
#     'market_cap': 0.23927499271977215,
#     'market_cap_dominance': 5543,
#     'fully_diluted_market_cap': 0.8992152617215479,
#     'last_updated': '2022-05-14T14:58:24.227Z'}}}]

# %%
crypto_id = data["data"]["id"]
crypto_name = data["data"]["name"]

# %%
import pandas as pd

# %%
data["data"][0].keys()
# Out:
# dict_keys(['id', 'name', 'symbol', 'slug', 'cmc_rank', 'num_market_pairs', 'circulating_supply', 'total_supply', 'max_supply', 'last_updated', 'date_added', 'tags', 'platform', 'self_reported_circulating_supply', 'self_reported_market_cap', 'quote'])

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
