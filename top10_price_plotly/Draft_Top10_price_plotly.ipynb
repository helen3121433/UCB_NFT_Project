# %%
import pandas as pd

pandas_df = pd.read_csv('attributes_of_top_7_collections/cleaned_almost_famous_pandas.csv')
# pandas_df.head()
degenerate_df = pd.read_csv('attributes_of_top_7_collections/cleaned_degenerate_ape_academy.csv')
geckos_df = pd.read_csv('attributes_of_top_7_collections/cleaned_galactic_geckos.csv')
guildsaga_df = pd.read_csv('attributes_of_top_7_collections/cleaned_guild_saga_heroes.csv')
magicticket_df = pd.read_csv('attributes_of_top_7_collections/cleaned_magicticket.csv')
magnum_df = pd.read_csv('attributes_of_top_7_collections/cleaned_magnum_ai.csv')
monkelabs_df = pd.read_csv('attributes_of_top_7_collections/cleaned_monkelabs_dao.csv')

# %%
pandas_df.head()
# Out:
#    Unnamed: 0                                            id  price  \
# 0           0  27gDWHQCryqpfDN7bf1ThQrySWJFJKSEbmFyyximNSak   0.58
# 1           1  7jrvBATdBbDVdqFgCVXyMbGNMLwWFWcL5Mn1hyJJfSwa   0.60
# 2           2  2wYNkFLm5AixJAWHSk8ZqvJavK5HPMNXi6XYAcAiU5tK   0.60
# 3           3  4Kw2W3ejGYGF4pBSNxyVeujMU84WauK2vzb9pA84ViCe   0.60
# 4           4  8rknZJsGVKRpzmNhUBpJhU3FW1ND4weUEPNDm24i9KqQ   0.64
#
#                                           owner        collectionName  \
# 0  BoL3yjzMt5qsCuat8AuuAZi3tD9CkEgTk4Y6KezYVeWP  almost_famous_pandas
# 1  DeBm9DxgZ5X8TECuQdag5RJLvGULeA4HfWhEWp2aed9a  almost_famous_pandas
# 2  HWv3PL1fGFxPT5PtzwQXQpdvu48oNoAkRcrezJTuKFJX  almost_famous_pandas
# 3  2wvTtheNr5suAWKKLvskZPcriuzaNLUcse8QfFr7mFSK  almost_famous_pandas
# 4  9UNbwFEefFhSZ6A6Udgag6WVQZJTiSgZguwJQG4P7mNi  almost_famous_pandas
#
#         collectionTitle                                                img  \
# ...

# %%
pandas_df = pandas_df.sort_values(by='price', ascending=False)
pandas_df.head()
# Out:
#       index  Unnamed: 0                                            id  \
# 1389   1389        1389  CcTQTfrQEETmKHLcvCqqUy1tStAwNKVgDuCrdgxtwsba
# 6074   6074        6074  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ
# 1388   1388        1388  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ
# 4539   4539        4539  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ
# 2913   2913        2913  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ
#
#           price                                         owner  \
# 1389  1000000.0  4CM3gkyJC5vip9wkXgjhKpsqc468yxSxrpZigk8wHzSV
# 6074    99999.0  2froCtjMQk4ic1yfB3oArtiV3Ga9jxy3Gt78mEpDZHgx
# 1388    99999.0  2froCtjMQk4ic1yfB3oArtiV3Ga9jxy3Gt78mEpDZHgx
# 4539    99999.0  2froCtjMQk4ic1yfB3oArtiV3Ga9jxy3Gt78mEpDZHgx
# 2913    99999.0  2froCtjMQk4ic1yfB3oArtiV3Ga9jxy3Gt78mEpDZHgx
#
#             collectionName       collectionTitle  \
# 1389  almost_famous_pandas  Almost Famous Pandas
# 6074  almost_famous_pandas  Almost Famous Pandas
# ...

# %%
pandas_df = pandas_df.sort_values(by='price', ascending=False)
new_df = pandas_df[pandas_df['img'].notna()]
new_df = new_df.reset_index()
# new_df.head(10)
test_df = new_df.head(10)
test_df.head(10)
# Out:
#    index  Unnamed: 0                                            id      price  \
# 0   1389        1389  CcTQTfrQEETmKHLcvCqqUy1tStAwNKVgDuCrdgxtwsba  1000000.0
# 1   1388        1388  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 2   1387        1387  5J81s5mT8ZJCWQx57gAvFX295uGjaJNp8cFn5H9Rtrg3    50000.0
# 3   1386        1386  EafvQSVK3tBmMTiQFCkjzQfqqUsMACC3A1jVrfHZJnjG     7777.0
# 4   1385        1385  FthHyRE7N7gmNjStLtES75s9LD3C9uZrjsRTEL4ujCeb     3500.0
# 5   1384        1384  31L7EKbk7bDJUhehCc6WbPBytLpAjWxJAWsUoHdZHNaN     3500.0
# 6   1383        1383  6pzCXkqvoS3qpcAXGQ87mQ9paKA5iaHinf1g1oH6v6T5     1250.0
# 7   1382        1382  AzE16ototCLY6VtSvinq6DkGGcHrfVnv2LfdHG98XCae     1001.0
# 8   1380        1380  3BqHF6s6eFfHWKPrM8foGMFWbekEeBmD2sJrNTNwTLXE     1000.0
# 9   1381        1381  88bhg7AGf18ZjWE1ursNgdbor84TCZYAxe1Q1JxFjLWP     1000.0
#
#                                           owner        collectionName  \
# ...

# %%
test_df.columns
# Out:
# Index(['index', 'Unnamed: 0', 'id', 'price', 'owner', 'collectionName',
#        'collectionTitle', 'img', 'title', 'propertyCategory', 'creators',
#        'attributes', 'properties', 'tokenDelegateValid', 'rarity', 'version',
#        'origin_attributes', 'Outfit', 'Head', 'Glasses', 'Eyes', 'Extras',
#        'Skin', 'Mouth', 'Body', 'Background', 'Face'],
#       dtype='object')

# %%
test_df['c_att'] = "Outfit: " + test_df['Outfit'] + "<br>" + \
                    "Head: " + test_df['Head'] + "<br>" + \
                    "Glasses: " + test_df['Glasses'] + "<br>" + \
                    "Eyes: " + test_df['Eyes'] + "<br>" + \
                    "Extras: " + test_df['Extras'] + "<br>" + \
                    "Skin: " + test_df['Skin'] + "<br>" + \
                    "Mouth: " + test_df['Mouth'] + "<br>" + \
                    "Body: " + test_df['Body'] + "<br>" + \
                    "Background: " + test_df['Background'] + "<br>" + \
                    "Face: " + test_df['Face'] + "<br>"
test_df.head()
# Out:
# C:\Users\xzhan\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#    index  Unnamed: 0                                            id      price  \
# 0   1389        1389  CcTQTfrQEETmKHLcvCqqUy1tStAwNKVgDuCrdgxtwsba  1000000.0
# 1   1388        1388  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 2   1387        1387  5J81s5mT8ZJCWQx57gAvFX295uGjaJNp8cFn5H9Rtrg3    50000.0
# 3   1386        1386  EafvQSVK3tBmMTiQFCkjzQfqqUsMACC3A1jVrfHZJnjG     7777.0
# 4   1385        1385  FthHyRE7N7gmNjStLtES75s9LD3C9uZrjsRTEL4ujCeb     3500.0
#
# ...

# %%
test_df.to_csv("test_df.csv")

# %%
# pandas_df
# degenerate_df
# geckos_df
# guildsaga_df
# magicticket_df
# magnum_df
# monkelabs_df

# %%
degenerate_df = degenerate_df.sort_values(by=['price','img'], ascending = [False,True])
print(degenerate_df.shape)
degenerate_df.head()
# Out:
# (2027, 25)
#       Unnamed: 0                                            id    price  \
# 2026        2026  CCW5C6CQ1oCiAwXnsRdfHKHFdFdktA3c5qJ4pbRvvHMj  75000.0
# 1286        1286  CCW5C6CQ1oCiAwXnsRdfHKHFdFdktA3c5qJ4pbRvvHMj  75000.0
# 646          646  CCW5C6CQ1oCiAwXnsRdfHKHFdFdktA3c5qJ4pbRvvHMj  75000.0
# 1285        1285  7Yc5WF5ERfZQxxXcaCX1KMNJbk5RmsZGha8JrYgM6tsh  69420.0
# 2025        2025  AUpL1Gcfbq2eRG5A9QkxwTCtoCVfrZXdwS4DCoyhtoLD  20000.0
#
#                                              owner          collectionName  \
# 2026  93cNwUacwUxqoyQjjCMg8vsUxjYNi8DE6245DGfJfmkB  degenerate_ape_academy
# 1286  93cNwUacwUxqoyQjjCMg8vsUxjYNi8DE6245DGfJfmkB  degenerate_ape_academy
# 646   93cNwUacwUxqoyQjjCMg8vsUxjYNi8DE6245DGfJfmkB  degenerate_ape_academy
# 1285  5uiQsG82ctbZbbmv2zHCyxJyz6mGR7FWGBh7wsrnrD9w  degenerate_ape_academy
# 2025  HzGvURzMft7DnoKmyeuZRctDedyVk3Gm836LRU4KaTbJ  degenerate_ape_academy
#
# ...

# %%
dup_degenerate_df = degenerate_df.drop_duplicates(subset=['title','price'])
print(dup_degenerate_df.shape)
dup_degenerate_df.head()
# Out:
# (1526, 25)
#       Unnamed: 0                                            id    price  \
# 2026        2026  CCW5C6CQ1oCiAwXnsRdfHKHFdFdktA3c5qJ4pbRvvHMj  75000.0
# 1285        1285  7Yc5WF5ERfZQxxXcaCX1KMNJbk5RmsZGha8JrYgM6tsh  69420.0
# 2025        2025  AUpL1Gcfbq2eRG5A9QkxwTCtoCVfrZXdwS4DCoyhtoLD  20000.0
# 2024        2024  EdoekHuWTrszS9wWRm35N8zp881eCkW46xa5yG2vJk4E  13420.0
# 2023        2023  8Qdrgw89Xi591wDbbSHzWyY81a1RaefFcn9MJMBqWiEn  10069.0
#
#                                              owner          collectionName  \
# 2026  93cNwUacwUxqoyQjjCMg8vsUxjYNi8DE6245DGfJfmkB  degenerate_ape_academy
# 1285  5uiQsG82ctbZbbmv2zHCyxJyz6mGR7FWGBh7wsrnrD9w  degenerate_ape_academy
# 2025  HzGvURzMft7DnoKmyeuZRctDedyVk3Gm836LRU4KaTbJ  degenerate_ape_academy
# 2024  HzGvURzMft7DnoKmyeuZRctDedyVk3Gm836LRU4KaTbJ  degenerate_ape_academy
# 2023  74wwrNvc1mfkP8WkKrVVD3yvUy3hP95i7oTD5jkX6zat  degenerate_ape_academy
#
# ...

# %%
test_deg_df = dup_degenerate_df[dup_degenerate_df['img'].notna()]
test_deg_df
# Out:
#      Unnamed: 0                                            id   price  \
# 289         289  BD1Vu3m5zbsxkN5wHWz8dhjTVxJLGMXsPktG3EDo1Q1H  6969.0
# 288         288  9Un3Fb8cdaACRrfMLqyAEGDt4Fu1fJc9WVqifTVyErgP  5500.0
# 287         287  6yXLz5eZ5n5ZQYH11Lum4nWacqrzit9BdehaEPAyyihb  4000.0
# 286         286  3eYyjmw5SW7Zg9ZEiXGKATMoZyPwkC6HMUTP2E3GQtsb  3888.0
# 285         285  B4eiqAeaWL2MRUAvf5j616ywbD9M2APC3eV5GPiZFZRX  3333.0
# ..          ...                                           ...     ...
# 2             2  2VjAbb2M5ZRZaVs2Jid1x3ecorXKLxM84VNe16Ab4DzV    56.0
# 4             4  5VHaCCRxvwEbmUSUnkabFeRc4T2bjKrNg2TsvEnkNqjk    56.0
# 3             3  6cVKuRDAsGEe7wdrygAtJTAVVmAgDszrCNyMU79GPG3o    56.0
# 1             1  8ikcuAsH6tZdpoqZCRHbUAmBeGDf1WhVNsymbPr7m3FF    55.8
# 0             0  46sw2pB5cS7yfNvQ8cr4RdmmXFZZkULewzPHB83kZ248    55.0
#
#                                             owner          collectionName  \
# ...

# %%
test2_deg_df = degenerate_df[degenerate_df['img'].notna()]
test2_deg_df.head()
# Out:
#      Unnamed: 0                                            id   price  \
# 289         289  BD1Vu3m5zbsxkN5wHWz8dhjTVxJLGMXsPktG3EDo1Q1H  6969.0
# 288         288  9Un3Fb8cdaACRrfMLqyAEGDt4Fu1fJc9WVqifTVyErgP  5500.0
# 287         287  6yXLz5eZ5n5ZQYH11Lum4nWacqrzit9BdehaEPAyyihb  4000.0
# 286         286  3eYyjmw5SW7Zg9ZEiXGKATMoZyPwkC6HMUTP2E3GQtsb  3888.0
# 285         285  B4eiqAeaWL2MRUAvf5j616ywbD9M2APC3eV5GPiZFZRX  3333.0
#
#                                             owner          collectionName  \
# 289  9yTMGfZfBuQMBSxCMMtaAwuJbPWrY8YaXxaEbLssuaHL  degenerate_ape_academy
# 288  B6KVBGaHXuAJreyKKkiH4U8j8jKi3wyMBqpMKSEQbK4z  degenerate_ape_academy
# 287   h5sbxYhFYCwERGvg2t2RvdtooYTHi9Gip4eo6DX5Sv7  degenerate_ape_academy
# 286  2bcURY4ZTZqeAJgg47gFhynmf8aAXBr8xZ52HvpdyA25  degenerate_ape_academy
# 285  94zpwMXt99WPEZ5ir3R7k5XUTwCenaFzdGX3erSKscZN  degenerate_ape_academy
#
#             collectionTitle  \
# 289  Degenerate Ape Academy
# 288  Degenerate Ape Academy
# ...

# %%
dup_pandas_df = pandas_df.drop_duplicates(subset=['title'])
print(dup_pandas_df.shape)
dup_pandas_df.head()
# Out:
# (2633, 26)
#       Unnamed: 0                                            id      price  \
# 1389        1389  CcTQTfrQEETmKHLcvCqqUy1tStAwNKVgDuCrdgxtwsba  1000000.0
# 1388        1388  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 4538        4538  Egh394PBgt39NEceFUE5bY6g3jUwi159hBiKNKQMovtj    69420.0
# 2911        2911  5J81s5mT8ZJCWQx57gAvFX295uGjaJNp8cFn5H9Rtrg3    50000.0
# 4536        4536  EafvQSVK3tBmMTiQFCkjzQfqqUsMACC3A1jVrfHZJnjG     7777.0
#
#                                              owner        collectionName  \
# 1389  4CM3gkyJC5vip9wkXgjhKpsqc468yxSxrpZigk8wHzSV  almost_famous_pandas
# 1388  2froCtjMQk4ic1yfB3oArtiV3Ga9jxy3Gt78mEpDZHgx  almost_famous_pandas
# 4538  DGTqCwoUmACn32FQX25awVMKchQnZW66bExAJZoaMkrC  almost_famous_pandas
# 2911  8v5vMaCX3xy6eTyQf84cdaso1trbf51WYLtM4L8GWg7N  almost_famous_pandas
# 4536  Aa7gcnMQ9gvfABrHwG5mhYQjKKbVd936T3QdeGidJiru  almost_famous_pandas
#
# ...
