# %%
import pandas as pd

pandas_df = pd.read_csv('../attributes_of_top_7_collections/cleaned_almost_famous_pandas.csv')
# pandas_df.head()
degenerate_df = pd.read_csv('../attributes_of_top_7_collections/cleaned_degenerate_ape_academy.csv')
geckos_df = pd.read_csv('../attributes_of_top_7_collections/cleaned_galactic_geckos.csv')
guildsaga_df = pd.read_csv('../attributes_of_top_7_collections/cleaned_guild_saga_heroes.csv')
magicticket_df = pd.read_csv('../attributes_of_top_7_collections/cleaned_magicticket.csv')
magnum_df = pd.read_csv('../attributes_of_top_7_collections/cleaned_magnum_ai.csv')
monkelabs_df = pd.read_csv('../attributes_of_top_7_collections/cleaned_monkelabs_dao.csv')

# %%
geckos_df.dtypes
# Out:
# Unnamed: 0              int64
# id                     object
# price                 float64
# owner                  object
# collectionName         object
# collectionTitle        object
# img                    object
# title                  object
# propertyCategory       object
# creators               object
# attributes             object
# properties             object
# tokenDelegateValid       bool
# rarity                float64
# version                 int64
# origin_attributes      object
# Faction                object
# Body                   object
# Armor                  object
# Mouth                  object
# Helmet                 object
# Ears                   object
# Eyes                   object
# Attribute Count         int64
# dtype: object

# %%
pandas_df = pandas_df.sort_values(by='price', ascending=False)
new_df = pandas_df[pandas_df['img'].notna()]
new_df.head(10)
test_df = new_df.head(10)
test_df.head(10)
# Out:
#       Unnamed: 0                                            id      price  \
# 1389        1389  CcTQTfrQEETmKHLcvCqqUy1tStAwNKVgDuCrdgxtwsba  1000000.0
# 1388        1388  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 4539        4539  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 2913        2913  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 6074        6074  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 4538        4538  Egh394PBgt39NEceFUE5bY6g3jUwi159hBiKNKQMovtj    69420.0
# 2912        2912  Egh394PBgt39NEceFUE5bY6g3jUwi159hBiKNKQMovtj    69420.0
# 2911        2911  5J81s5mT8ZJCWQx57gAvFX295uGjaJNp8cFn5H9Rtrg3    50000.0
# 6073        6073  5J81s5mT8ZJCWQx57gAvFX295uGjaJNp8cFn5H9Rtrg3    50000.0
# 1387        1387  5J81s5mT8ZJCWQx57gAvFX295uGjaJNp8cFn5H9Rtrg3    50000.0
#
#                                              owner        collectionName  \
# 1389  4CM3gkyJC5vip9wkXgjhKpsqc468yxSxrpZigk8wHzSV  almost_famous_pandas
# ...

# %%
test_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'price', 'owner', 'collectionName',
#        'collectionTitle', 'img', 'title', 'propertyCategory', 'creators',
#        'attributes', 'properties', 'tokenDelegateValid', 'rarity', 'version',
#        'origin_attributes', 'Outfit', 'Head', 'Glasses', 'Eyes', 'Extras',
#        'Skin', 'Mouth', 'Body', 'Background', 'Face'],
#       dtype='object')

# %%
test_df['c_att'] = "Outfit: " + test_df['Outfit'] + "<br>" + "Head: " + test_df['Head'] + "<br>" + "Glasses: " + test_df['Glasses'] + "<br>" + "Eyes: " + test_df['Eyes'] + "<br>" + "Extras: " + test_df['Extras'] + "<br>" + "Skin: " + test_df['Skin'] + "<br>" + "Mouth: " + test_df['Mouth'] + "<br>" + "Body: " + test_df['Body'] + "<br>" + "Background: " + test_df['Background'] + "<br>" + "Face: " + test_df['Face'] + "<br>"
test_df.head()
# Out:
# C:\Users\xzhan\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       Unnamed: 0                                            id      price  \
# 1389        1389  CcTQTfrQEETmKHLcvCqqUy1tStAwNKVgDuCrdgxtwsba  1000000.0
# 1388        1388  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 4539        4539  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 2913        2913  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 6074        6074  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
#
#                                              owner        collectionName  \
# ...

# %%
test_df.to_csv("test_df.csv")

# %%
def getdata (collecions_df):
    collections_df = collections_df.sort_values(by='price', ascending=False)
    new_df = collections_df['img'].notna()
    top10 = co

# %%
collections_df = collections_df.sort_values(by='price', ascending=False)
collections_df.head()
# Out:
#                                                  id      price  \
# 6241   9AhB18EFize9kr11u3UWM1tiWP28hZaWzZ6BbyVGKwXa  3000000.0
# 10367  CcTQTfrQEETmKHLcvCqqUy1tStAwNKVgDuCrdgxtwsba  1000000.0
# 56181   XDKQbpZmMLB8dF1vUhT4MXPpRzGNyDvTR5Y9i2TWyY1   999999.0
# 24822   XDKQbpZmMLB8dF1vUhT4MXPpRzGNyDvTR5Y9i2TWyY1   999999.0
# 8714    XDKQbpZmMLB8dF1vUhT4MXPpRzGNyDvTR5Y9i2TWyY1   999999.0
#
#                                               owner        collectionName  \
# 6241   GHcq9EPQTZ1cxpdftyDEbD4AJY6Tb4dh12nnf1bwHTCG       iconicapeclub3d
# 10367  4CM3gkyJC5vip9wkXgjhKpsqc468yxSxrpZigk8wHzSV  almost_famous_pandas
# 56181  2yNjkQyn3heN16Zy8QV89Xq33dtbv2P2ExYRYcdEZato         space_runners
# 24822  2yNjkQyn3heN16Zy8QV89Xq33dtbv2P2ExYRYcdEZato         space_runners
# 8714   2yNjkQyn3heN16Zy8QV89Xq33dtbv2P2ExYRYcdEZato         space_runners
#
#             collectionTitle  \
# 6241     Iconic Ape Club 3D
# 10367  Almost Famous Pandas
# 56181         Space Runners
# ...

# %%
collections_df.price.describe()
# Out:
# count    6.321600e+04
# mean     2.668217e+02
# std      1.563489e+04
# min      1.750000e-01
# 25%      2.250000e+00
# 50%      6.690000e+00
# 75%      2.100000e+01
# max      3.000000e+06
# Name: price, dtype: float64

# %%
pandas_df = collections_df[collections_df['collectionName'] == 'almost_famous_pandas']
pandas_df.head()
# Out:
#                                                  id      price  \
# 10367  CcTQTfrQEETmKHLcvCqqUy1tStAwNKVgDuCrdgxtwsba  1000000.0
# 43029  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 57895  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 10366  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 26591  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
#
#                                               owner        collectionName  \
# 10367  4CM3gkyJC5vip9wkXgjhKpsqc468yxSxrpZigk8wHzSV  almost_famous_pandas
# 43029  2froCtjMQk4ic1yfB3oArtiV3Ga9jxy3Gt78mEpDZHgx  almost_famous_pandas
# 57895  2froCtjMQk4ic1yfB3oArtiV3Ga9jxy3Gt78mEpDZHgx  almost_famous_pandas
# 10366  2froCtjMQk4ic1yfB3oArtiV3Ga9jxy3Gt78mEpDZHgx  almost_famous_pandas
# 26591  2froCtjMQk4ic1yfB3oArtiV3Ga9jxy3Gt78mEpDZHgx  almost_famous_pandas
#
#             collectionTitle  \
# 10367  Almost Famous Pandas
# 43029  Almost Famous Pandas
# 57895  Almost Famous Pandas
# ...

# %%
# pandas_df = pandas_df.sort_values(by='price',ascending=False)
# pandas_df.head()

# %%
# first_value = pandas_df['img'].iat[0]

# %%
# first_value

# %%
# def gain_collection (c_name):
#     col_df = collections_df[collections_df['collectionName'] == c_name]
#     col_df = col_df.reset_index()
#     col_df = col_df.sort_values(by='price',ascending=False)
#     for x in col_df:
#         if col_df['']
#     top5_nft_df = col_df.head(10)
#     return top5_nft_df

# %%
# pandas = 'almost_famous_pandas'
# pandas_df = gain_collection(pandas)
# pandas_df.head()

# %%
# pandas_df.img.dtypes

# %%
# pandas_df['img'].dropna()

# %%
collections_df_2 = collections_df
collections_df_2 = collections_df[collections_df['img'].notna()]
collections_df_2
# Out:
#                                                  id         price  \
# 6241   9AhB18EFize9kr11u3UWM1tiWP28hZaWzZ6BbyVGKwXa  3.000000e+06
# 10367  CcTQTfrQEETmKHLcvCqqUy1tStAwNKVgDuCrdgxtwsba  1.000000e+06
# 8714    XDKQbpZmMLB8dF1vUhT4MXPpRzGNyDvTR5Y9i2TWyY1  9.999990e+05
# 8713   7eV8fer2eZcnyL4FK1p3brEuXKb8vfiHPywbarVobXYq  5.555550e+05
# 532    D3mgcboBJj8jFYsRgT6wyA8AwEmaTAvNdGp8VfuwTAXA  9.999900e+04
# ...                                             ...           ...
# 6689   8oixGnfskp5E7SwFS3HzWmurib2P2UPNsaeRYJDcRSAD  5.700000e-01
# 6688   9CTXJRuHsfW7Xx6ehpGAvkkN3Z9oDrGyBZ8HbxZM3wF5  5.700000e-01
# 6687   3U2zs7fBkUicygKjZTV4wF4PShdk59MfYNX3wXFNRDDK  5.696969e-01
# 6685   9KL6tgB39D7fyNwBcjky7C7XvjdVsa4ueQvx7phGVjaV  5.600000e-01
# 6682   J5GfqZeaUpZgP25JxJ44aZhPP3KGLSaoyqpr83ozGvpx  5.000000e-01
#
#                                               owner           collectionName  \
# 6241   GHcq9EPQTZ1cxpdftyDEbD4AJY6Tb4dh12nnf1bwHTCG          iconicapeclub3d
# ...

# %%
def gain_collection (c_name):
    col_df = collections_df_2[collections_df_2['collectionName'] == c_name]
    col_df = col_df.reset_index()
    col_df = col_df.sort_values(by='price',ascending=False)
    top5_nft_df = col_df.head(10)
    return top5_nft_df

# %%
pandas = 'almost_famous_pandas'
pandas_df = gain_collection(pandas)
pandas_df.head()
# Out:
#    index                                            id      price  \
# 0  10367  CcTQTfrQEETmKHLcvCqqUy1tStAwNKVgDuCrdgxtwsba  1000000.0
# 1  10366  BDY8JqE4BpQMrKwLNMYnUNXskx8xzpHzdcYAqD7DY6sZ    99999.0
# 2  10365  5J81s5mT8ZJCWQx57gAvFX295uGjaJNp8cFn5H9Rtrg3    50000.0
# 3  10364  EafvQSVK3tBmMTiQFCkjzQfqqUsMACC3A1jVrfHZJnjG     7777.0
# 4  10363  FthHyRE7N7gmNjStLtES75s9LD3C9uZrjsRTEL4ujCeb     3500.0
#
#                                           owner        collectionName  \
# 0  4CM3gkyJC5vip9wkXgjhKpsqc468yxSxrpZigk8wHzSV  almost_famous_pandas
# 1  2froCtjMQk4ic1yfB3oArtiV3Ga9jxy3Gt78mEpDZHgx  almost_famous_pandas
# 2  8v5vMaCX3xy6eTyQf84cdaso1trbf51WYLtM4L8GWg7N  almost_famous_pandas
# 3  Aa7gcnMQ9gvfABrHwG5mhYQjKKbVd936T3QdeGidJiru  almost_famous_pandas
# 4  FfjdA4H2oJAzptYgD9njzW4ieodfJqeU7JYP2hJh4ZE5  almost_famous_pandas
#
#         collectionTitle                                                img  \
# ...

# %%
magicticket = 'magicticket'
magicticket_df = gain_collection(magicticket)
magicticket_df.head()
# Out:
#    index                                            id   price  \
# 0   7730  GSmpHNbM6xQWfhvnMjrH54DjDHEjKhXXL5d1upgy9pyC  6900.0
# 1   7729  Dct4k9psRJ7u1zck37BCD5Uy7Qk4Vm1tREt2TWkfKZ5j  2023.0
# 2   7728  8ERsMg9vWytVMwUdVuBnzuxEnxD1Kj3JFtB6nAyL7ZVA  2022.0
# 3   7727  GfiFrosGDgztmpvRnGkSdRX95tLzmXrUoSb5f96g1TTT  1070.0
# 4   7726  HpT8MLC8Eq8KwWqB9idvnFEJeWaKG3i7ZzSHa2yyQH1f   500.0
#
#                                           owner collectionName  \
# 0  JDTAgnrsN83PAFaQ1MiyW5xGcdFCBTweGWy11izPFAqA    magicticket
# 1  2Y7PXPEgpYXXEvKL7xU2AuUZYdEARCdeP6nWfXwmJ5FP    magicticket
# 2  2zfskkfN6QLnHuHHV7gwtyotVfbUg69JbXjPwY9DngAP    magicticket
# 3  97C7AH3JhQBM2umZ66ZhonKefdMesHzsd4T2QzaHNh3X    magicticket
# 4  93fSAu78sUATCikaDFCWpHAxR6ziZFFK7jNabGFU218m    magicticket
#
#   collectionTitle                                                img  \
# 0    Magic Ticket  https://bafybeihr7vi77syiup5o4avvzemhlp4v4nplp...
# ...

# %%
guild_saga_heroes = 'guild_saga_heroes'
guild_saga_heroes_df = gain_collection(guild_saga_heroes)
guild_saga_heroes_df.head()
# Out:
#    index                                            id   price  \
# 0   5604  BLNtxpb1gRn27JbEeEptK5AnJFo6npce2fmeVNhpjVUY  5555.0
# 1   5603  5XrDui64dSS9qhqyyPFRd3X6ykBRviu2iMqSt4puJMSZ   279.0
# 2   5602  78Xnqh2nEwGbrLzV13E9ci7ZnN7qVE131LxZwsuyY8FA   200.0
# 3   5601  Bs4McXpoh6SgW3xodz5QnGeoPbxk7GVBEkwPnNZZsiqi   150.0
# 4   5599  8Z753ABswmeKBNj8pn4FXqKUUCUKexpzjAxTgV86eUTb   150.0
#
#                                           owner     collectionName  \
# 0   SUtJbde33heALYkjn9WXandEvXmCunGr3h2RkTx5qRJ  guild_saga_heroes
# 1  FFDTcCW6UXKpkMnCefTRLpF8ZkJtS4sbGTjkcNU31Pxh  guild_saga_heroes
# 2  6rXGLWZhdAsoYs2mGEYCfm4nMQ3rxqbWx6c8syVo7hpm  guild_saga_heroes
# 3  AX1yd9bPhUPQaeFZ5qdpfTBgMRjZfXPkuoSo7ArbJvfD  guild_saga_heroes
# 4  7Thv8Bj6kUePvtmBzsE3RGaWGvvKEmNHkrPyZh5n6PSJ  guild_saga_heroes
#
#      collectionTitle                                                img  \
# 0  Guild Saga Heroes  https://gldhero-production.s3.amazonaws.com/77...
# ...

# %%
monkelabs_dao = 'monkelabs_dao'
monkelabs_dao_df = gain_collection(monkelabs_dao)
monkelabs_dao_df.head()
# Out:
#    index                                            id    price  \
# 0   3729  9oN97cHobD88LXyJ1r6u3pfN3i3z5uCYz2CiDqy4BZvs  1111.00
# 1   3728  8gbVVs5FKUKR5LGdMdoz2oq6xJDDcfpoVLUbda325AkK   550.00
# 2   3727  G7MbrB4TVSEtSMsHaGD3TNMhyEReBiY91Uy8PWXmj9Uo   500.00
# 3   3726  2nB16Sks5C7EcxuRiYD7Z7n41fVBVv6jftVMhgUgMboP   444.00
# 4   3725  CDPe5KQr7ktWxxTFA62ASj1qNda8s1wMYsnZMRXunkz2   420.69
#
#                                           owner collectionName  \
# 0  AB9im7U5Jiwio5KWQpY6Uo6wyHGxHcNtbS4kuerhMrgH  monkelabs_dao
# 1  AB9im7U5Jiwio5KWQpY6Uo6wyHGxHcNtbS4kuerhMrgH  monkelabs_dao
# 2  EwazXuP58ekKWxjrCNY9PcKomc8Dh83vmq7R7wjoHjgM  monkelabs_dao
# 3  AB9im7U5Jiwio5KWQpY6Uo6wyHGxHcNtbS4kuerhMrgH  monkelabs_dao
# 4  2EcHKQDF4H3cQvXRMfuzdMgVxRXJG4tToQEfXHeosPN4  monkelabs_dao
#
#   collectionTitle                                                img  \
# 0   MonkeLabs DAO  https://monkelabs.nyc3.digitaloceanspaces.com/...
# ...

# %%
galactic_geckos = 'galactic_geckos'
galactic_geckos_df = gain_collection(galactic_geckos)
galactic_geckos_df.head()
# Out:
#    index                                            id    price  \
# 0   2830  CEsDXKwum3PBh1b8tt9F42EsG2zgbFXCNwCudjTpVDxf  10000.0
# 2   2829  8EDSHD9CS9xQPmmYxRDZGAFHvHQCKmRZdpabtXEGF5hF   3000.0
# 1   2828  DhwtneM46kxTSbqaVbkzdayxwcsjQwnkwYUTG5gzAb4W   3000.0
# 3   2827  AUFchxCNn9uwZ512aQHF8xedwAiVxKCi2KLrBY68AFru   2500.0
# 4   2826  8L9kFMmRUenzXy1pYzq9ZMehhW82cYZvKrRVvvWX1ELD   2500.0
#
#                                           owner   collectionName  \
# 0  3BjsntftfwXMfxGH8VrK7JqVSmKs3pxgHxZzsvau7Pq7  galactic_geckos
# 2  8Qf78Mk1swwsmEzEPcTHDEGhSYchjT74NTYgCsQW5CNP  galactic_geckos
# 1  DK1Qf2qpKeJdbgrnVDiMukyG3RBKF91REG8GXc2xHLVL  galactic_geckos
# 3  4cLzduP6b9LCALYS2bk8KSe7Tbc72fagjccrXtYNyJ5o  galactic_geckos
# 4  E4EgwkVQ8UDdQNhg1Lu3owybheW26rG7zHAFq6153bpV  galactic_geckos
#
#          collectionTitle                                                img  \
# 0  GGSG: Galactic Geckos  https://www.arweave.net/oWaoGB2YTOfCLAOCdewMlJ...
# ...

# %%
magnum_ai = 'magnum_ai'
magnum_ai_df = gain_collection(magnum_ai)
magnum_ai_df.head()
# Out:
#    index                                            id   price  \
# 0  14556  6u68JX7jNMbUcWjmkkWghrEpMjh3ZJyZviCLxmn5cSrC  666.00
# 1  14555  EYvKPfz5wag6qfE5BvyqhJv9teg7JFJ2w1yZp5Hd8ZdQ  200.00
# 2  14554  5waiGM6WPLCU8vqTL2oifRVZwLAdk577WsgLf3Nqn2Y9  111.00
# 3  14553  DKFkLKSFDWMG3uft47masyA4h4J2uUncjBtHstySegme   75.00
# 4  14552  3PUjzireCaCx2YG6QHT5Ly4DGDZ3EhXPBUYr3AVnZTfF   69.69
#
#                                           owner collectionName  \
# 0  4uGCh7CsC9kT4x71K9oSBidE3BWpzzUogzfdD3KmkbtM      magnum_ai
# 1  3eXbrSeq4DFbdihZ6kzEmDGYkKbCKsCyxZQMTowi8fXn      magnum_ai
# 2  22qmfs8tyqJ2q89EQJcp5Bt1ugJPXsaBuvfPhELHBgbc      magnum_ai
# 3  GxEKHxxnn73vgDTYD5Waon51xXfFLKkWDdbxXMMSnLjY      magnum_ai
# 4  6LZD77tzrCmGBi6SYuqJyVGkt9zyVfi864pWmNELJzzi      magnum_ai
#
#   collectionTitle                                                img  \
# 0       Magnum AI  https://www.arweave.net/_Kzevw2p4A9Cuixk8io9vz...
# ...

# %%
degenerate_ape_academy = 'degenerate_ape_academy'
degenerate_ape_academy_df = gain_collection(degenerate_ape_academy)
degenerate_ape_academy_df.head()
# Out:
#    index                                            id   price  \
# 0   8277  BD1Vu3m5zbsxkN5wHWz8dhjTVxJLGMXsPktG3EDo1Q1H  6969.0
# 1   8276  9Un3Fb8cdaACRrfMLqyAEGDt4Fu1fJc9WVqifTVyErgP  5500.0
# 2   8275  6yXLz5eZ5n5ZQYH11Lum4nWacqrzit9BdehaEPAyyihb  4000.0
# 3   8274  3eYyjmw5SW7Zg9ZEiXGKATMoZyPwkC6HMUTP2E3GQtsb  3888.0
# 4   8273  B4eiqAeaWL2MRUAvf5j616ywbD9M2APC3eV5GPiZFZRX  3333.0
#
#                                           owner          collectionName  \
# 0  9yTMGfZfBuQMBSxCMMtaAwuJbPWrY8YaXxaEbLssuaHL  degenerate_ape_academy
# 1  B6KVBGaHXuAJreyKKkiH4U8j8jKi3wyMBqpMKSEQbK4z  degenerate_ape_academy
# 2   h5sbxYhFYCwERGvg2t2RvdtooYTHi9Gip4eo6DX5Sv7  degenerate_ape_academy
# 3  2bcURY4ZTZqeAJgg47gFhynmf8aAXBr8xZ52HvpdyA25  degenerate_ape_academy
# 4  94zpwMXt99WPEZ5ir3R7k5XUTwCenaFzdGX3erSKscZN  degenerate_ape_academy
#
#           collectionTitle                                                img  \
# ...

# %%
pandas_df.to_csv('top_10_nft_almost_famous_pandas.csv')
magicticket_df.to_csv('top_10_nft_magicticket.csv')
guild_saga_heroes_df.to_csv('top_10_nft_guild_saga_heroes.csv')
monkelabs_dao_df.to_csv('top_10_nft_monkelabs_dao.csv')
galactic_geckos_df.to_csv('top_10_nft_galactic_geckos.csv')
magnum_ai_df.to_csv('top_10_nft_magnum_ai.csv')
degenerate_ape_academy_df.to_csv('top_10_nft_degenerate_ape_academy.csv')
